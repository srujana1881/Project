# %% [markdown]
# # Model Evaluation

# %%
binary_eval = BinaryClassificationEvaluator(labelCol="label")
multi_eval = MulticlassClassificationEvaluator(labelCol="label")

# %%
def evaluate_model(name, pred):
    return {
        "Model": name,
        "AUC": binary_eval.evaluate(pred),
        "Accuracy": multi_eval.evaluate(pred, {multi_eval.metricName:"accuracy"}),
        "F1": multi_eval.evaluate(pred, {multi_eval.metricName:"f1"})
    }

# %%
results = [
    evaluate_model("Logistic Regression", lr_pred),
    evaluate_model("Decision Tree", dt_pred),
    evaluate_model("Random Forest", rf_pred),
    evaluate_model("GBT", gbt_pred)
]

# %%
performance_df = pd.DataFrame(results)

# %%
performance_df
# Out:
#                  Model       AUC  Accuracy        F1
# 0  Logistic Regression  0.684806  0.642023  0.637443
# 1        Decision Tree  0.669246  0.704408  0.704296
# 2        Random Forest  0.742630  0.677255  0.675504
# 3                  GBT  0.780684  0.705622  0.705578

# %%
performance_df.to_csv("dashboard2_model_performance.csv", index=False)

# %% [markdown]
# # Model Serialization

# %%
lr_model.write().overwrite().save("models/lr_model")
rf_model.write().overwrite().save("models/rf_model")
